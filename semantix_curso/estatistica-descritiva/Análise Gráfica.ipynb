# %% [markdown]
# # Algumas representações gráficas
#
# * Visualização rápida.
# * Compreensão do comportamento de uma determinada variável.
#
#
# ## 1. Histograma
#
# * Estudo de variáveis quantitativas, principalmente as contínuas.
# * Distribuição de frequência por intervalo.
# * Comportamento das variáveis.
# * Propor distribuição teóricas com objetivo de fazer modelagem.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr

# %%
np.random.seed(seed=0)
x = np.random.normal(size = 1000)
y = np.random.gamma(2, 2, 1000)
z = np.random.weibull(10.,1000)

# %%
fig, ax =plt.subplots(1,3,figsize=(10,5))
plt.tight_layout(2)

sns.distplot(x,bins=10, ax=ax[0], color='darkviolet').set_title('X')
sns.distplot(y,bins=10, ax=ax[1]).set_title('Y')
sns.distplot(z,bins=10, ax=ax[2], color='violet').set_title('Z')
# Out:
# <ipython-input-6-6f3144225b49>:2: MatplotlibDeprecationWarning: Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.
#   plt.tight_layout(2)
# C:\Users\Semantix\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Semantix\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Semantix\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Z')

# %% [markdown]
# ## 2. Boxplot
#
# * Visualização baseada em quartis.
# * Estudo de variáveis quantitativas.
# * Relação entre variáveis quantitativas e qualitativas.
# * Comportamento das variáveis.
# * Visualização de outliers.

# %% [markdown]
# ![boxplot.PNG](attachment:boxplot.PNG)

# %%
fig, ax =plt.subplots(1,3,figsize=(15,5))
plt.tight_layout(2)

sns.boxplot(x, ax=ax[0], showmeans=True, color='darkviolet').set_title('X')
sns.boxplot(y, ax=ax[1], showmeans=True).set_title('Y')
sns.boxplot(z, ax=ax[2], showmeans=True, color='violet').set_title('Z')
# Out:
# <ipython-input-100-795c19824eef>:2: MatplotlibDeprecationWarning: Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.
#   plt.tight_layout(2)
# C:\Users\Semantix\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Semantix\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Semantix\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Z')

# %% [markdown]
# ## 3. Diagrama de dispersão
#
# * Relação e intensidade entre duas variáveis quantitativas.

# %% [markdown]
# ![grafico_dispers%C3%A3o.jpg](attachment:grafico_dispers%C3%A3o.jpg)
